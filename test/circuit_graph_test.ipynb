# %%
import networkx as nx
from circuit_graph import CircuitGraph

# %% [markdown]
# ### Many 2-branch Loops

# %%
s = CircuitGraph()
s.addBranch(0, 1, "L1")
s.addBranch(0, 1, "L2")
s.addBranch(0, 1, "C1")
s.addBranch(0, 1, "I1")
s.addBranch(0, 1, "I2")
s.addBranch(0, 1, "C2")

# %%
print("Superconducting loops")
print(s.sc_loops)
print()
print("Closure branches")
print(s.closure_branches)
print()
print("Component map")
print(s.components_map)
print()
print("All loops")
print(s.loops_map)
print()
print("Loop Adjacency")
print(s.loop_adjacency_map)
# Out:
# Superconducting loops
# {0: [(0, 1, 0), (1, 0, 3)], 1: [(0, 1, 0), (1, 0, 4)], 2: [(0, 1, 0), (1, 0, 1)]}
#
# Closure branches
# [(1, 0, 3), (1, 0, 4), (1, 0, 1)]
#
# Component map
# {(0, 1, 0): 'L1', (0, 1, 1): 'L2', (0, 1, 2): 'C1', (0, 1, 3): 'I1', (0, 1, 4): 'I2', (0, 1, 5): 'C2', (1, 0, 0): 'L1', (1, 0, 1): 'L2', (1, 0, 2): 'C1', (1, 0, 3): 'I1', (1, 0, 4): 'I2', (1, 0, 5): 'C2'}
#
# All loops
# {0: [(0, 1, 0), (0, 1, 1)], 1: [(0, 1, 1), (0, 1, 2)], 2: [(0, 1, 2), (0, 1, 3)], 3: [(0, 1, 3), (0, 1, 4)], 4: [(0, 1, 4), (0, 1, 5)]}
#
# Loop Adjacency
# {(0, 1): [(0, 1, 1)], (1, 2): [(0, 1, 2)], (2, 3): [(0, 1, 3)], (3, 4): [(0, 1, 4)]}

# %%
graph_drawings = ["Circuit","Conductive","SCTree","SCGraph"]
s.drawGraphViz(graph="Circuit")

# %%
s.drawGraphViz(graph="Conductive")

# %%
s.drawGraphViz(graph="SCTree")

# %%
s.drawGraphViz(graph="SCGraph")

# %%
s.drawGraphViz(graph="Loop")

# %% [markdown]
# ### Floating 2-branch Loops

# %%
s = CircuitGraph()
s.addBranch(0, 1, "Cf")
s.addBranch(1, 2, "L")
s.addBranch(1, 2, "C")
s.addBranch(1, 2, "I")

# %%
print("Superconducting loops")
print(s.sc_loops)
print()
print("Closure branches")
print(s.closure_branches)
print()
print("Component map")
print(s.components_map)
print()
print("All loops")
print(s.loops_map)
print()
print("Loop Adjacency")
print(s.loop_adjacency_map)
# Out:
# Superconducting loops
# {0: [(1, 2, 0), (2, 1, 2)]}
#
# Closure branches
# [(2, 1, 2)]
#
# Component map
# {(0, 1, 0): 'Cf', (1, 2, 0): 'L', (1, 2, 1): 'C', (1, 2, 2): 'I', (1, 0, 0): 'Cf', (2, 1, 0): 'L', (2, 1, 1): 'C', (2, 1, 2): 'I'}
#
# All loops
# {0: [(1, 2, 0), (1, 2, 1)], 1: [(1, 2, 1), (1, 2, 2)]}
#
# Loop Adjacency
# {(0, 1): [(1, 2, 1)]}

# %%
graph_drawings = ["Circuit","Conductive","SCTree","SCGraph"]
s.drawGraphViz(graph="Circuit")

# %%
s.drawGraphViz(graph="Conductive")

# %%
s.drawGraphViz(graph="SCTree")

# %%
s.drawGraphViz(graph="SCGraph")

# %%
s.drawGraphViz(graph="Loop")

# %% [markdown]
# ### Coupled Loops

# %%
s = CircuitGraph()
s.addBranch(0, 1, "L1")
s.addBranch(0, 1, "C1")
s.addBranch(0, 1, "I1")
s.addBranch(0, 2, "L2")
s.addBranch(0, 2, "C2")
s.addBranch(0, 2, "I2")
s.addBranch(0, 3, "L3")
s.addBranch(0, 3, "C3")
s.addBranch(0, 3, "I3")
s.addBranch(1, 2, "Cc12")
s.addBranch(2, 3, "Cc23")

# %%
print("Superconducting loops")
print(s.sc_loops)
print()
print("Closure branches")
print(s.closure_branches)
print()
print("Component map")
print(s.components_map)
print()
print("All loops")
print(s.loops_map)
print()
print("Loop Adjacency")
print(s.loop_adjacency_map)
# Out:
# Superconducting loops
# {0: [(0, 1, 0), (1, 0, 2)], 1: [(0, 2, 0), (2, 0, 2)], 2: [(0, 3, 0), (3, 0, 2)]}
#
# Closure branches
# [(1, 0, 2), (2, 0, 2), (3, 0, 2)]
#
# Component map
# {(0, 1, 0): 'L1', (0, 1, 1): 'C1', (0, 1, 2): 'I1', (0, 2, 0): 'L2', (0, 2, 1): 'C2', (0, 2, 2): 'I2', (0, 3, 0): 'L3', (0, 3, 1): 'C3', (0, 3, 2): 'I3', (1, 2, 0): 'Cc12', (2, 3, 0): 'Cc23', (1, 0, 0): 'L1', (1, 0, 1): 'C1', (1, 0, 2): 'I1', (2, 0, 0): 'L2', (2, 0, 1): 'C2', (2, 0, 2): 'I2', (3, 0, 0): 'L3', (3, 0, 1): 'C3', (3, 0, 2): 'I3', (2, 1, 0): 'Cc12', (3, 2, 0): 'Cc23'}
#
# All loops
# {0: [(0, 1, 0), (0, 1, 1)], 1: [(0, 1, 1), (0, 1, 2)], 2: [(0, 2, 0), (0, 2, 1)], 3: [(0, 2, 1), (0, 2, 2)], 4: [(0, 3, 0), (0, 3, 1)], 5: [(0, 3, 1), (0, 3, 2)], 6: [(1, 2, 0), (0, 2, 0), (0, 1, 0)], 7: [(2, 3, 0), (0, 2, 1), (0, 3, 0)]}
#
# Loop Adjacency
# ...

# %%
graph_drawings = ["Circuit","Conductive","SCTree","SCGraph"]
s.drawGraphViz(graph="Circuit")

# %%
s.drawGraphViz(graph="Conductive")

# %%
s.drawGraphViz(graph="SCTree")

# %%
s.drawGraphViz(graph="SCGraph")

# %%
s.drawGraphViz(graph="Loop")

# %% [markdown]
# ### Grounded Complicated Circuit

# %%
s = CircuitGraph()
s.addBranch(0, 1, "C1z")
s.addBranch(0, 1, "I1z")
s.addBranch(1, 4, "C1x")
s.addBranch(1, 4, "I1x")
s.addBranch(4, 2, "L1x")
s.addBranch(2, 5, "L2x")
s.addBranch(5, 1, "C2x")
s.addBranch(5, 1, "I2x")
s.addBranch(2, 3, "C2z")
s.addBranch(2, 3, "I2z")
s.addBranch(3, 0, "Lz")

# %%
print("Superconducting loops")
print(s.sc_loops)
print()
print("Closure branches")
print(s.closure_branches)
print()
print("Component map")
print(s.components_map)
print()
print("All loops")
print(s.loops_map)
print()
print("Loop Adjacency")
print(s.loop_adjacency_map)
# Out:
# Superconducting loops
# {0: [(0, 3, 0), (4, 2, 0), (1, 4, 1), (0, 1, 1), (3, 2, 1)], 1: [(1, 5, 1), (4, 2, 0), (1, 4, 1), (5, 2, 0)]}
#
# Closure branches
# [(3, 2, 1), (5, 2, 0)]
#
# Component map
# {(0, 1, 0): 'C1z', (0, 1, 1): 'I1z', (0, 3, 0): 'Lz', (1, 4, 0): 'C1x', (1, 4, 1): 'I1x', (1, 5, 0): 'C2x', (1, 5, 1): 'I2x', (4, 2, 0): 'L1x', (2, 5, 0): 'L2x', (2, 3, 0): 'C2z', (2, 3, 1): 'I2z', (1, 0, 0): 'C1z', (1, 0, 1): 'I1z', (3, 0, 0): 'Lz', (4, 1, 0): 'C1x', (4, 1, 1): 'I1x', (5, 1, 0): 'C2x', (5, 1, 1): 'I2x', (2, 4, 0): 'L1x', (5, 2, 0): 'L2x', (3, 2, 0): 'C2z', (3, 2, 1): 'I2z'}
#
# All loops
# {0: [(0, 1, 0), (0, 1, 1)], 1: [(1, 4, 0), (1, 4, 1)], 2: [(1, 5, 0), (1, 5, 1)], 3: [(2, 3, 0), (2, 3, 1)], 4: [(1, 5, 0), (2, 5, 0), (2, 3, 0), (0, 3, 0), (0, 1, 0)], 5: [(1, 4, 0), (2, 4, 0), (2, 3, 1), (0, 3, 0), (0, 1, 1)]}
#
# Loop Adjacency
# ...

# %%
graph_drawings = ["Circuit","Conductive","SCTree","SCGraph"]
s.drawGraphViz(graph="Circuit")

# %%
s.drawGraphViz(graph="Conductive")

# %%
s.drawGraphViz(graph="SCTree")

# %%
s.drawGraphViz(graph="SCGraph")

# %%
s.drawGraphViz(graph="Loop")
